# %%
import os
import numpy as np

import tensorflow as tf
import tensorflow_addons as tfa
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
print(tf.__version__)
AUTOTUNE = tf.data.experimental.AUTOTUNE

import deepcell
# Changed from before due to new placement of Track, concat_tracks
from deepcell_tracking.utils import load_trks
from deepcell.data.tracking import Track, concat_tracks
##############
from sklearn.model_selection import train_test_split
from deepcell.utils.data_utils import reshape_movie
from deepcell.utils.transform_utils import erode_edges
from deepcell.data import split_dataset
from deepcell_toolbox.processing import normalize, histogram_normalization

import spektral
# Out:
# 2.8.0

# %%
os.listdir('/training/tracking-nuclear')
# Out:
# ['val.trks',
#  'inputs.yaml',
#  'metadata.yaml',
#  'train.trks',
#  '.gitignore',
#  'params.yaml',
#  'dvc.yaml',
#  'dvc.lock',
#  'data-source.npz',
#  'test.trks']

# %%
# %%time
path_temp_trks = '/training/tracking-nuclear/test.trks'
all_data = [load_trks(path_temp_trks)]
# Out:
# CPU times: user 15 s, sys: 1.65 s, total: 16.7 s
# Wall time: 16.7 s

# %%
# %%time
all_tracks = [Track(tracked_data=d) for d in all_data]
# Out:
# 100%|███████████████████████████████████████████| 12/12 [00:48<00:00,  4.03s/it]
# 100%|███████████████████████████████████████████| 12/12 [00:54<00:00,  4.53s/it]
# 2022-06-28 10:32:55.381003: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-28 10:32:55.954687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10415 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:09:00.0, compute capability: 6.1
# CPU times: user 7min 21s, sys: 9min 26s, total: 16min 47s
# Wall time: 1min 55s

# %% [markdown]
# # Actually takes <2 minutes

# %%
# %%time
track_info = concat_tracks(all_tracks)
# Out:
# CPU times: user 343 ms, sys: 535 ms, total: 878 ms
# Wall time: 875 ms

# %%
for k, v in track_info.items():
    print(k, v.shape)
# Out:
# appearances (12, 71, 331, 32, 32, 1)
# centroids (12, 71, 331, 2)
# morphologies (12, 71, 331, 3)
# adj_matrices (12, 71, 331, 331)
# norm_adj_matrices (12, 71, 331, 331)
# temporal_adj_matrices (12, 70, 331, 331, 3)

# %%
from skimage.exposure import rescale_intensity

def norm(X):
    X_norm = histogram_normalization(X, kernel_size=32)
    
    X_rescaled = np.zeros(X_norm.shape)
    for batch in range(X.shape[0]):
        for frame in range(X.shape[1]):
            x = X[batch, frame]
            x = rescale_intensity(x, out_range=(0,1))
            X_rescaled[batch, frame] = x
            
    return X_rescaled

def prepare_dataset(track_info, batch_size=1, buffer_size=256,
                    seed=None, val_split=0.2):
    
    # Merge tracks along the batch axis
    appearances = track_info['appearances']
    
    app_shape = np.shape(appearances)
    appearances = np.swapaxes(appearances, 1,2) #(0,2,1,3,4,5))
    appearances = np.reshape(appearances, [-1, app_shape[1], app_shape[3], app_shape[4], app_shape[5]])
    
    # Normalize appearances
    appearances = norm(appearances)
    
    input_dict = {'appearances': appearances}
    
    output_dict = {'appearances_decoder': appearances}
    
    dataset = tf.data.Dataset.from_tensor_slices((input_dict, output_dict))
    
    dataset = dataset.shuffle(buffer_size, seed=seed)
    
    # split into train/val
    # need to add test_data since split_dataset now creates a test dataset
    # test_size is 0 by default
    train_data, val_data, test_data = split_dataset(dataset, val_split)
    
    # batch the data
    train_data = train_data.repeat().batch(batch_size)
    val_data = val_data.repeat().batch(batch_size)
    data = dataset.repeat().batch(batch_size)
    
    # prefetch the data
    train_data = train_data.prefetch(tf.data.AUTOTUNE)
    val_data = val_data.prefetch(tf.data.AUTOTUNE)
    data = dataset.prefetch(tf.data.AUTOTUNE)
    
    return train_data, val_data

# %%
train_data, val_data = prepare_dataset(track_info, batch_size=1)
# Out:
# WARNING:root:Found constant value array in batch 7 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 8 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 9 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 10 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 11 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 12 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 13 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 14 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 15 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 16 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 17 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 18 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 19 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 20 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 21 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 22 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 23 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 24 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 25 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 26 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 27 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 28 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 29 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 30 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 31 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 32 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 33 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 34 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 35 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 36 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 37 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 38 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 39 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 40 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 41 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 42 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 43 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 44 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 45 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 46 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 47 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 48 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 49 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 50 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 51 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 52 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 53 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 54 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 55 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 56 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 57 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 58 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 59 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 60 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 61 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 62 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 63 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 64 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 65 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 66 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 67 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 68 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 69 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 70 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 71 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 72 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 73 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 74 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 75 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 76 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 77 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 78 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 79 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 80 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 81 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 82 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 83 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 84 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 85 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 86 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 87 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 88 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 89 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 90 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 91 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 92 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 93 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 94 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 95 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 96 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 97 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 98 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 99 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 100 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 101 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 102 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 103 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 104 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 105 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 106 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 107 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 108 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 109 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 110 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 111 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 112 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 113 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 114 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 115 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 116 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 117 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 118 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 119 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 120 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 121 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 122 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 123 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 124 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 125 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 126 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 127 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 128 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 129 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 130 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 131 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 132 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 133 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 134 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 135 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 136 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 137 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 138 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 139 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 140 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 141 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 142 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 143 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 144 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 145 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 146 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 147 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 148 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 149 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 150 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 151 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 152 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 153 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 154 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 155 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 156 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 157 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 158 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 159 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 160 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 161 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 162 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 163 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 164 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 165 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 166 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 167 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 168 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 169 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 170 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 171 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 172 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 173 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 174 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 175 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 176 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 177 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 178 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 179 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 180 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 181 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 182 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 183 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 184 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 185 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 186 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 187 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 188 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 189 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 190 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 191 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 192 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 193 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 194 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 195 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 196 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 197 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 198 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 199 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 200 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 201 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 202 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 203 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 204 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 205 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 206 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 207 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 208 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 209 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 210 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 211 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 212 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 213 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 214 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 215 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 216 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 217 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 218 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 219 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 220 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 221 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 222 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 223 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 224 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 225 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 226 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 227 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 228 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 229 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 230 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 231 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 232 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 233 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 234 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 235 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 236 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 237 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 238 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 239 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 240 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 241 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 242 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 243 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 244 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 245 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 246 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 247 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 248 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 249 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 250 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 251 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 252 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 253 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 254 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 255 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 256 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 257 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 258 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 259 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 260 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 261 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch
and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3859 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3860 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3861 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3862 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3863 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3864 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3865 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3866 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3867 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3868 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3869 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3870 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3871 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3872 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3873 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3874 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3875 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3876 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3877 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3878 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3879 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3880 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3881 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3882 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3883 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3884 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3885 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3886 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3887 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3888 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3889 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3890 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3891 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3892 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3893 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3894 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3895 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3896 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3897 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3898 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3899 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3900 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3901 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3902 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3903 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3904 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3905 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3906 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3907 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3908 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3909 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3910 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3911 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3912 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3913 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3914 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3915 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3916 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3917 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3918 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3919 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3920 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3921 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3922 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3923 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3924 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3925 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3926 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3927 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3928 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3929 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3930 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3931 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3932 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3933 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3934 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3935 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3936 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3937 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3938 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3939 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3940 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3941 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3942 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3943 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3944 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3945 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3946 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3947 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3948 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3949 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3950 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3951 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3952 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3953 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3954 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3955 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3956 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3957 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3958 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3959 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3960 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3961 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3962 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3963 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3964 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3965 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3966 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3967 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3968 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3969 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3970 and channel 0. Normalizing as zeros.
# WARNING:root:Found constant value array in batch 3971 and channel 0. Normalizing as zeros.

# %%
it = iter(train_data)

# %% [markdown]
# # When the shuffle is performed, none of the life cycles seem to have images at all.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(4,20,figsize=(20,10))
for ax in axes.flatten():
    ax.set_axis_off()

nxt = it.next()
for j in range(71):
    axes.flatten()[j].imshow(nxt[0]['appearances'][0,j])
    axes.flatten()[j].set_axis_off()

# %%
fig, axes = plt.subplots(4,20,figsize=(20,10))
for ax in axes.flatten():
    ax.set_axis_off()

nxt = it.next()
for j in range(71):
    axes.flatten()[j].imshow(nxt[0]['appearances'][0,j])
    axes.flatten()[j].set_axis_off()

# %%
fig, axes = plt.subplots(4,20,figsize=(20,10))
for ax in axes.flatten():
    ax.set_axis_off()

nxt = it.next()
for j in range(71):
    axes.flatten()[j].imshow(nxt[0]['appearances'][0,j])
    axes.flatten()[j].set_axis_off()

# %%
fig, axes = plt.subplots(4,20,figsize=(20,10))
for ax in axes.flatten():
    ax.set_axis_off()

nxt = it.next()
for j in range(71):
    axes.flatten()[j].imshow(nxt[0]['appearances'][0,j])
    axes.flatten()[j].set_axis_off()

# %%
fig, axes = plt.subplots(4,20,figsize=(20,10))
for ax in axes.flatten():
    ax.set_axis_off()

nxt = it.next()
for j in range(71):
    axes.flatten()[j].imshow(nxt[0]['appearances'][0,j])
    axes.flatten()[j].set_axis_off()

# %%
fig, axes = plt.subplots(4,20,figsize=(20,10))
for ax in axes.flatten():
    ax.set_axis_off()

nxt = it.next()
for j in range(71):
    axes.flatten()[j].imshow(nxt[0]['appearances'][0,j])
    axes.flatten()[j].set_axis_off()

# %%
fig, axes = plt.subplots(4,20,figsize=(20,10))
for ax in axes.flatten():
    ax.set_axis_off()

nxt = it.next()
for j in range(71):
    axes.flatten()[j].imshow(nxt[0]['appearances'][0,j])
    axes.flatten()[j].set_axis_off()
